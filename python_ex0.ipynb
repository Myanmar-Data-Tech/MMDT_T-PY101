# %% [markdown]
# <a href="https://colab.research.google.com/github/phyo-thandar/MMDT_T-PY101/blob/master/python_ex0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
usd = 2000
bp = usd * 0.82
print("USD "+ str(usd) + " is equivalent to " + str (bp))
# Out:
# USD 2000 is equivalent to 1640.0

# %%
import sys
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'
